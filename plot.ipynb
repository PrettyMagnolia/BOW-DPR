# %%
import matplotlib.pyplot as plt

# 数据
dpr = [0.46, 0.535, 0.575, 0.6, 0.62, 0.65, 0.655, 0.67, 0.675, 0.69, 0.705, 0.72, 0.72, 0.72, 0.725, 0.73, 0.73, 0.735, 0.735, 0.735, 0.735, 0.735, 0.735, 0.74, 0.75, 0.75, 0.755, 0.755, 0.76, 0.765, 0.765, 0.765, 0.765, 0.765, 0.765, 0.765, 0.765, 0.765, 0.765, 0.765, 0.765, 0.765, 0.765, 0.765, 0.765, 0.77, 0.77, 0.775, 0.775, 0.775, 0.775, 0.775, 0.775, 0.775, 0.775, 0.775, 0.775, 0.775, 0.775, 0.78, 0.78, 0.78, 0.78, 0.785, 0.785, 0.785, 0.785, 0.785, 0.785, 0.785, 0.785, 0.785, 0.785, 0.785, 0.785, 0.785, 0.785, 0.795, 0.795, 0.795, 0.795, 0.795, 0.795, 0.795, 0.795, 0.795, 0.795, 0.8, 0.8, 0.8, 0.805, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81, 0.81]
taser = [0.43, 0.555, 0.6, 0.64, 0.66, 0.675, 0.71, 0.73, 0.73, 0.745, 0.75, 0.755, 0.755, 0.755, 0.755, 0.76, 0.76, 0.76, 0.76, 0.76, 0.76, 0.76, 0.76, 0.76, 0.77, 0.775, 0.78, 0.785, 0.785, 0.785, 0.785, 0.785, 0.785, 0.785, 0.785, 0.785, 0.79, 0.795, 0.8, 0.8, 0.8, 0.8, 0.815, 0.815, 0.815, 0.815, 0.82, 0.825, 0.825, 0.825, 0.825, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.835, 0.835, 0.835, 0.835, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84]
bowdpr = [0.57, 0.615, 0.66, 0.675, 0.68, 0.69, 0.71, 0.72, 0.73, 0.74, 0.755, 0.755, 0.755, 0.755, 0.755, 0.755, 0.755, 0.76, 0.76, 0.76, 0.765, 0.77, 0.77, 0.77, 0.78, 0.79, 0.79, 0.79, 0.79, 0.805, 0.805, 0.805, 0.805, 0.805, 0.805, 0.805, 0.805, 0.815, 0.815, 0.82, 0.82, 0.825, 0.825, 0.825, 0.825, 0.825, 0.825, 0.825, 0.825, 0.825, 0.825, 0.825, 0.83, 0.83, 0.83, 0.83, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.84, 0.84, 0.84, 0.84, 0.845, 0.845, 0.845, 0.845, 0.845, 0.85, 0.855, 0.855, 0.855, 0.855, 0.855, 0.86, 0.86, 0.86, 0.865, 0.865, 0.865, 0.865, 0.865, 0.865, 0.865, 0.865]
print(len(dpr), len(taser), len(bowdpr))

# 创建x轴数据为数组下标
x = range(1, len(bowdpr) + 1)  # x轴的范围为1到数据的长度

# 绘图
plt.plot(x, dpr, label='DPR', color='b')  # 绘制DPR曲线，蓝色
plt.plot(x, taser, label='TASER', color='g')  # 绘制TASER曲线，绿色
plt.plot(x, bowdpr, label='BOW-DPR', color='r')  # 绘制BOWDPR曲线，红色

# 添加图例
plt.legend()

# 设置标题和标签
plt.title("Comparison of hit@k")
plt.xlabel("k")
plt.ylabel("hit@k")

# 显示图表
plt.show()
# Out:
# 100 100 100

# %%
with open('/home/yifei/code/IR/BOW-DPR/result_hit@k.csv', 'r' ) as f:
    lines = f.readlines()
    res = []
    for line in lines:
        res.append(eval(line.split(',')[-1].strip()))
print(res)
# Out:
# [0.57, 0.615, 0.66, 0.675, 0.68, 0.69, 0.71, 0.72, 0.73, 0.74, 0.755, 0.755, 0.755, 0.755, 0.755, 0.755, 0.755, 0.76, 0.76, 0.76, 0.765, 0.77, 0.77, 0.77, 0.78, 0.79, 0.79, 0.79, 0.79, 0.805, 0.805, 0.805, 0.805, 0.805, 0.805, 0.805, 0.805, 0.815, 0.815, 0.82, 0.82, 0.825, 0.825, 0.825, 0.825, 0.825, 0.825, 0.825, 0.825, 0.825, 0.825, 0.825, 0.83, 0.83, 0.83, 0.83, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.835, 0.84, 0.84, 0.84, 0.84, 0.845, 0.845, 0.845, 0.845, 0.845, 0.85, 0.855, 0.855, 0.855, 0.855, 0.855, 0.86, 0.86, 0.86, 0.865, 0.865, 0.865, 0.865, 0.865, 0.865, 0.865, 0.865]
